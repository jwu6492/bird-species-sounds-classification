# %%
import os
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %%
X=[]
Z=[]
IMG_SIZE=150
duck_dir= '../birds/train/Duck'
grebe_dir= '../birds/train/Grebe'
hawk_dir= '../birds/train/Hawk'
humming_bird_dir= '../birds/train/Humming_bird'
owl_dir= '../birds/train/Owl'
sparrow_dir= '../birds/train/Sparrow'

# %%
def assign_label(img,label):
    return label

# %%
def make_train_data(label,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,label)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Duck',duck_dir)
print(len(X))
# Out:
# 100%|██████████| 600/600 [00:03<00:00, 177.22it/s]
# 600

# %%
make_train_data('Grebe',grebe_dir)
print(len(X))
# Out:
# 100%|██████████| 602/602 [00:03<00:00, 178.05it/s]
# 1202

# %%
make_train_data('Hawk', hawk_dir)
print(len(X))
# Out:
# 100%|██████████| 600/600 [00:03<00:00, 186.04it/s]
# 1802

# %%
make_train_data('Hawk', hawk_dir)
print(len(X))
# Out:
# 100%|██████████| 600/600 [00:02<00:00, 232.12it/s]
# 2402

# %%
make_train_data('Humming Bird', humming_bird_dir)
print(len(X))
# Out:
# 100%|██████████| 600/600 [00:03<00:00, 183.11it/s]
# 3002

# %%
make_train_data('Owl', owl_dir)
print(len(X))
# Out:
# 100%|██████████| 600/600 [00:03<00:00, 168.96it/s]
# 3602

# %%
make_train_data('Sparrow', sparrow_dir)
print(len(X))
# Out:
# 100%|██████████| 618/618 [00:03<00:00, 171.81it/s]
# 4220

# %%
#random 10 images
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Bird: '+Z[l])
        
plt.tight_layout()

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,6)
X=np.array(X)
X=X/255

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %%
# # modelling starts using a CNN.

model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 

model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(6, activation = "softmax"))

# %%
batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 96)          83040
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 96)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               786944
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 3078
# =================================================================
# Total params: 1,032,422
# Trainable params: 1,032,422
# Non-trainable params: 0
# _________________________________________________________________

# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
history = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# WARNING:tensorflow:From <ipython-input-21-a96a2d6ce6b7>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 24/24 [==============================] - 47s 2s/step - loss: 1.6729 - accuracy: 0.2986 - val_loss: 1.6313 - val_accuracy: 0.3005
# Epoch 2/50
# 24/24 [==============================] - 43s 2s/step - loss: 1.5645 - accuracy: 0.3306 - val_loss: 1.5698 - val_accuracy: 0.3175
# Epoch 3/50
# 24/24 [==============================] - 46s 2s/step - loss: 1.5289 - accuracy: 0.3757 - val_loss: 1.6092 - val_accuracy: 0.3185
# Epoch 4/50
# 24/24 [==============================] - 41s 2s/step - loss: 1.4628 - accuracy: 0.4027 - val_loss: 1.4237 - val_accuracy: 0.4123
# Epoch 5/50
# 24/24 [==============================] - 42s 2s/step - loss: 1.3999 - accuracy: 0.4560 - val_loss: 1.3969 - val_accuracy: 0.4569
# Epoch 6/50
# 24/24 [==============================] - 42s 2s/step - loss: 1.3301 - accuracy: 0.4791 - val_loss: 1.3188 - val_accuracy: 0.4673
# Epoch 7/50
# 24/24 [==============================] - 46s 2s/step - loss: 1.2795 - accuracy: 0.5077 - val_loss: 1.2512 - val_accuracy: 0.4948
# Epoch 8/50
# 24/24 [==============================] - 43s 2s/step - loss: 1.2656 - accuracy: 0.5193 - val_loss: 1.2195 - val_accuracy: 0.5327
# Epoch 9/50
# 24/24 [==============================] - 42s 2s/step - loss: 1.2160 - accuracy: 0.5255 - val_loss: 1.2034 - val_accuracy: 0.5071
# Epoch 10/50
# 24/24 [==============================] - 43s 2s/step - loss: 1.1529 - accuracy: 0.5515 - val_loss: 1.1779 - val_accuracy: 0.5517
# Epoch 11/50
# 24/24 [==============================] - 43s 2s/step - loss: 1.1199 - accuracy: 0.5608 - val_loss: 1.0659 - val_accuracy: 0.5858
# Epoch 12/50
# 24/24 [==============================] - 42s 2s/step - loss: 1.0904 - accuracy: 0.5828 - val_loss: 1.0924 - val_accuracy: 0.5659
# Epoch 13/50
# 24/24 [==============================] - 43s 2s/step - loss: 1.0937 - accuracy: 0.5779 - val_loss: 1.0376 - val_accuracy: 0.5905
# Epoch 14/50
# 24/24 [==============================] - 44s 2s/step - loss: 1.0507 - accuracy: 0.5822 - val_loss: 1.0085 - val_accuracy: 0.6209
# Epoch 15/50
# 24/24 [==============================] - 42s 2s/step - loss: 1.0203 - accuracy: 0.5878 - val_loss: 1.0836 - val_accuracy: 0.5801
# Epoch 16/50
# 24/24 [==============================] - 43s 2s/step - loss: 1.0075 - accuracy: 0.6078 - val_loss: 0.9215 - val_accuracy: 0.6427
# Epoch 17/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.9453 - accuracy: 0.6246 - val_loss: 0.9777 - val_accuracy: 0.6161
# Epoch 18/50
# 24/24 [==============================] - 45s 2s/step - loss: 0.9225 - accuracy: 0.6421 - val_loss: 0.9354 - val_accuracy: 0.6360
# Epoch 19/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.9146 - accuracy: 0.6368 - val_loss: 0.8907 - val_accuracy: 0.6540
# Epoch 20/50
# 24/24 [==============================] - 43s 2s/step - loss: 0.8765 - accuracy: 0.6473 - val_loss: 0.9930 - val_accuracy: 0.6209
# Epoch 21/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.8578 - accuracy: 0.6664 - val_loss: 0.8897 - val_accuracy: 0.6682
# Epoch 22/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.8252 - accuracy: 0.6780 - val_loss: 0.9053 - val_accuracy: 0.6673
# Epoch 23/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.8117 - accuracy: 0.6826 - val_loss: 0.9072 - val_accuracy: 0.6616
# Epoch 24/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.7791 - accuracy: 0.6994 - val_loss: 0.8654 - val_accuracy: 0.6739
# Epoch 25/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.7826 - accuracy: 0.6895 - val_loss: 0.8640 - val_accuracy: 0.6682
# Epoch 26/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.7730 - accuracy: 0.7000 - val_loss: 0.8852 - val_accuracy: 0.6692
# Epoch 27/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.7610 - accuracy: 0.7046 - val_loss: 0.8192 - val_accuracy: 0.6986
# Epoch 28/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.7577 - accuracy: 0.7066 - val_loss: 0.8855 - val_accuracy: 0.6758
# Epoch 29/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.7247 - accuracy: 0.7168 - val_loss: 0.7700 - val_accuracy: 0.7166
# Epoch 30/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.7258 - accuracy: 0.7204 - val_loss: 0.9029 - val_accuracy: 0.6739
# Epoch 31/50
# 24/24 [==============================] - 44s 2s/step - loss: 0.7261 - accuracy: 0.7218 - val_loss: 0.7755 - val_accuracy: 0.7213
# Epoch 32/50
# 24/24 [==============================] - 44s 2s/step - loss: 0.6993 - accuracy: 0.7260 - val_loss: 0.7831 - val_accuracy: 0.7137
# Epoch 33/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.6782 - accuracy: 0.7372 - val_loss: 0.8108 - val_accuracy: 0.6919
# Epoch 34/50
# 24/24 [==============================] - 46s 2s/step - loss: 0.6660 - accuracy: 0.7372 - val_loss: 0.7774 - val_accuracy: 0.7175
# Epoch 35/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.6570 - accuracy: 0.7405 - val_loss: 0.8271 - val_accuracy: 0.7185
# Epoch 36/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.6194 - accuracy: 0.7593 - val_loss: 0.7994 - val_accuracy: 0.7043
# Epoch 37/50
# 24/24 [==============================] - 45s 2s/step - loss: 0.6580 - accuracy: 0.7455 - val_loss: 0.7766 - val_accuracy: 0.7194
# Epoch 38/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.6091 - accuracy: 0.7633 - val_loss: 0.7739 - val_accuracy: 0.7299
# Epoch 39/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.6170 - accuracy: 0.7646 - val_loss: 0.7853 - val_accuracy: 0.7147
# Epoch 40/50
# 24/24 [==============================] - 42s 2s/step - loss: 0.5977 - accuracy: 0.7725 - val_loss: 0.7617 - val_accuracy: 0.7374
# Epoch 41/50
# 24/24 [==============================] - 43s 2s/step - loss: 0.5672 - accuracy: 0.7738 - val_loss: 0.7155 - val_accuracy: 0.7545
# Epoch 42/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.5796 - accuracy: 0.7774 - val_loss: 0.7810 - val_accuracy: 0.7194
# Epoch 43/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.5564 - accuracy: 0.7893 - val_loss: 0.7319 - val_accuracy: 0.7507
# Epoch 44/50
# 24/24 [==============================] - 43s 2s/step - loss: 0.5377 - accuracy: 0.7926 - val_loss: 0.7631 - val_accuracy: 0.7365
# Epoch 45/50
# 24/24 [==============================] - 44s 2s/step - loss: 0.5380 - accuracy: 0.7942 - val_loss: 0.7200 - val_accuracy: 0.7346
# Epoch 46/50
# 24/24 [==============================] - 44s 2s/step - loss: 0.5316 - accuracy: 0.7916 - val_loss: 0.7306 - val_accuracy: 0.7507
# Epoch 47/50
# 24/24 [==============================] - 44s 2s/step - loss: 0.5217 - accuracy: 0.8047 - val_loss: 0.6971 - val_accuracy: 0.7507
# Epoch 48/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.5087 - accuracy: 0.8090 - val_loss: 0.7003 - val_accuracy: 0.7611
# Epoch 49/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.4706 - accuracy: 0.8192 - val_loss: 0.7088 - val_accuracy: 0.7526
# Epoch 50/50
# 24/24 [==============================] - 41s 2s/step - loss: 0.4765 - accuracy: 0.8189 - val_loss: 0.7358 - val_accuracy: 0.7441
